# %% [markdown]
# # Default notebook
#
# This default notebook is executed using a Lakeflow job as defined in resources/sample_job.job.yml.

# %%
# Set default catalog and schema
catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")
spark.sql(f"USE CATALOG {catalog}")
spark.sql(f"USE SCHEMA {schema}")
# Out:
# c:\Users\Mohana krishna kapa\Desktop\dbricks\RestAPIProj\RestAPIProj\.venv\Lib\site-packages\databricks\sdk\_widgets\__init__.py:71: UserWarning:
# To use databricks widgets interactively in your notebook, please install databricks sdk using:
# 	pip install 'databricks-sdk[notebook]'
# Falling back to default_value_only implementation for databricks widgets.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Set default catalog and schema
# ----> 2 catalog = dbutils.widgets.get("catalog")
#       3 schema = dbutils.widgets.get("schema")
#       4 spark.sql(f"USE CATALOG {catalog}")
#
# File c:\Users\Mohana krishna kapa\Desktop\dbricks\RestAPIProj\RestAPIProj\.venv\Lib\site-packages\databricks\sdk\_widgets\__init__.py:10, in WidgetUtils.get(self, name)
#       9 def get(self, name: str):
# ---> 10     return self._get(name)
#
# File c:\Users\Mohana krishna kapa\Desktop\dbricks\RestAPIProj\RestAPIProj\.venv\Lib\site-packages\databricks\sdk\_widgets\default_widgets_utils.py:42, in DefaultValueOnlyWidgetUtils._get(self, name)
#      41 def _get(self, name: str) -> str:
# ---> 42     return self._widgets[name]
#
# KeyError: 'catalog'

# %%
import sys

sys.path.append("../src")
from RestAPI import taxis

taxis.find_all_taxis().show(10)
# Out:
# +--------------------+---------------------+-------------+-----------+----------+-----------+
# |tpep_pickup_datetime|tpep_dropoff_datetime|trip_distance|fare_amount|pickup_zip|dropoff_zip|
# +--------------------+---------------------+-------------+-----------+----------+-----------+
# | 2016-02-13 21:47:53|  2016-02-13 21:57:15|          1.4|        8.0|     10103|      10110|
# | 2016-02-13 18:29:09|  2016-02-13 18:37:23|         1.31|        7.5|     10023|      10023|
# | 2016-02-06 19:40:58|  2016-02-06 19:52:32|          1.8|        9.5|     10001|      10018|
# | 2016-02-12 19:06:43|  2016-02-12 19:20:54|          2.3|       11.5|     10044|      10111|
# | 2016-02-23 10:27:56|  2016-02-23 10:58:33|          2.6|       18.5|     10199|      10022|
# | 2016-02-13 00:41:43|  2016-02-13 00:46:52|          1.4|        6.5|     10023|      10069|
# | 2016-02-18 23:49:53|  2016-02-19 00:12:53|         10.4|       31.0|     11371|      10003|
# | 2016-02-18 20:21:45|  2016-02-18 20:38:23|        10.15|       28.5|     11371|      11201|
# | 2016-02-03 10:47:50|  2016-02-03 11:07:06|         3.27|       15.0|     10014|      10023|
# | 2016-02-19 01:26:39|  2016-02-19 01:40:01|         4.42|       15.0|     10003|      11222|
# +--------------------+---------------------+-------------+-----------+----------+-----------+
# only showing top 10 rows
